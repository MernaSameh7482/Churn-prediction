# %% [markdown]
# <a href="https://colab.research.google.com/github/MernaSameh7482/Churn-prediction/blob/main/Churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 38.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
#Main libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize': [15, 9]}, font_scale=1.3)

#Preprocessing
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import OneHotEncoder

#Algorithmsz
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

#Tuning
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#Metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

#Import required libraries
import matplotlib.pyplot as plt  #import matplotlib for visualization
import numpy as np #imports a fast numerical programming library
import pandas as pd #imports panda for easy data analysis and manipulation
from sklearn.model_selection import train_test_split #import train_test_split function from model_selction module
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
from sklearn import metrics #imports metrics model to check for accuracy
from sklearn.ensemble import RandomForestClassifier

# %%
'''# Read the train and test CSV files
df = pd.read_csv("/content/oversampled_data_train.csv")
test_df = pd.read_csv("/content/oversampled_data_test.csv")

# Concatenate the DataFrames along the rows (axis=0)
#df = pd.concat([train_df, test_df], ignore_index=True)'''
# Out:
# '# Read the train and test CSV files\ndf = pd.read_csv("/content/oversampled_data_train.csv")\ntest_df = pd.read_csv("/content/oversampled_data_test.csv")\n\n# Concatenate the DataFrames along the rows (axis=0)\n#df = pd.concat([train_df, test_df], ignore_index=True)'

# %%
#test_df.isnull().sum()

# %%
#combined_df

# %%
df = pd.read_csv('/content/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
# Assuming 'selected_rows' contains the filtered dataframe
attrition_counts = df['Attrition'].value_counts()

attrition_counts.plot(kind='bar')
plt.title('Attrition Counts for Age > 30')
plt.xlabel('Attrition')
plt.ylabel('Count')
plt.show()

# %%
# Data to plot
labels = ['Travel_Rarely ', 'Travel_Frequently', 'Non-Travel ']
sizes = [1043, 277, 150]
colors = ['green', 'yellowgreen', 'lightcoral']

# Plot the first bar chart
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)  # Create a subplot with 1 row and 2 columns, and select the first subplot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Plot the second bar chart
plt.subplot(1, 2, 2)  # Select the second subplot
plt.bar(labels, sizes, color=colors)
# Out:
# <BarContainer object of 3 artists>

# %%
# Data to plot
labels = ['Research & Development ', 'Sales ', 'Human Resources ']
sizes = df['Department'].value_counts()
colors = ['green', 'yellowgreen', 'lightcoral']

# Plot the first bar chart
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)  # Create a subplot with 1 row and 2 columns, and select the first subplot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Plot the second bar chart
plt.subplot(1, 2, 2)  # Select the second subplot
plt.bar(labels, sizes, color=colors)
# Out:
# <BarContainer object of 3 artists>

# %%
labels = ['Life Sciences  ', 'Medical ', 'Marketing','Technical Degree','Other','Human Resources']
sizes = df['EducationField'].value_counts()
colors = plt.cm.rainbow(np.linspace(0, 1, len(labels)))

# Plot the first bar chart
plt.figure(figsize = [18, 5])
plt.subplot(1, 2, 1)  # Create a subplot with 1 row and 2 columns, and select the first subplot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Plot the second bar chart
plt.subplot(1, 2, 2)  # Select the second subplot
plt.bar(labels, sizes, color=colors)
# Out:
# <BarContainer object of 6 artists>

# %%
labels = ['male', 'female']
sizes  = df['Gender'].value_counts()
colors = ['green', 'lightcoral']

# Plot the first bar chart
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)  # Create a subplot with 1 row and 2 columns, and select the first subplot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Plot the second bar chart
plt.subplot(1, 2, 2)  # Select the second subplot
plt.bar(labels, sizes, color=colors)
# Out:
# <BarContainer object of 2 artists>

# %%
labels = [' Sales Executive ', 'Research Scientist  ', 'Laboratory Technician','Manufacturing Director','Healthcare Representative ','Manager','Sales Representative','Research Director','Human Resources']
sizes = df['JobRole'].value_counts()
colors = plt.cm.rainbow(np.linspace(0, 1, len(labels)))

# Plot the first bar chart
plt.figure(figsize = [20,8])
plt.subplot(1, 2, 1)  # Create a subplot with 1 row and 2 columns, and select the first subplot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Plot the second bar chart
plt.subplot(1, 2, 2)  # Select the second subplot
plt.bar(labels, sizes, color=colors)
plt.xticks(rotation=90);

# %%
# Data to plot
labels = ['Married', 'Single ', 'Divorced']
sizes = df['MaritalStatus'].value_counts()
colors = ['green', 'yellowgreen', 'lightcoral']

# Plot the first bar chart
plt.figure(figsize = [15, 5])
plt.subplot(1, 2, 1)  # Create a subplot with 1 row and 2 columns, and select the first subplot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Plot the second bar chart
plt.subplot(1, 2, 2)  # Select the second subplot
plt.bar(labels, sizes, color=colors)
plt.grid(axis='y', linestyle='--', linewidth=0.5)

# %%
import plotly.express as px
rate_att=df.groupby(['MonthlyIncome','Attrition']).apply(lambda x:x['MonthlyIncome'].count()).reset_index(name='Counts')
rate_att['MonthlyIncome']=round(rate_att['MonthlyIncome'],-3)
rate_att=rate_att.groupby(['MonthlyIncome','Attrition']).apply(lambda x:x['MonthlyIncome'].count()).reset_index(name='Counts')
fig=px.line(rate_att,x='MonthlyIncome',y='Counts',color='Attrition',title='Monthly Income basis counts of People in an Organization')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
JobRole_att=df.groupby(['JobRole','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
fig=px.bar(JobRole_att,x='JobRole',y='Counts',color='Attrition',title='JobRole wise Counts of People in an Organization')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsAtCompany=df.groupby(['YearsAtCompany','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsAtCompany,x='YearsAtCompany',y='Counts',color='Attrition',title='YearsAtCompany Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsSinceLastPromotion=df.groupby(['YearsSinceLastPromotion','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsSinceLastPromotion,x='YearsSinceLastPromotion',y='Counts',color='Attrition',title='YearsSinceLastPromotion Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsInCurrentRole=df.groupby(['YearsInCurrentRole','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsInCurrentRole,x='YearsInCurrentRole',y='Counts',color='Attrition',title='YearsInCurrentRole Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsWithCurrManager=df.groupby(['YearsWithCurrManager','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsWithCurrManager,x='YearsWithCurrManager',y='Counts',color='Attrition',title='YearsWithCurrManager Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
TotalWorkingYears=df.groupby(['TotalWorkingYears','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(TotalWorkingYears,x='TotalWorkingYears',y='Counts',color='Attrition',title='TotalWorkingYears Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
EnvironmentSatisfaction=df.groupby(['EnvironmentSatisfaction','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(EnvironmentSatisfaction,x='EnvironmentSatisfaction',y='Counts',color='Attrition',title='EnvironmentSatisfaction Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Determine attendance based on criteria
# For demonstration purposes, let's consider a combination of factors such as working hours, scheduled shifts, and overtime
# You can adjust the criteria based on your specific context and requirements

# Criteria 1: Working Hours
# Let's assume that employees who work fewer than 4 hours in a day are considered absent
#df['Attendance'] = '0'  # Initialize attendance column with default value
#df.loc[df['DailyRate'] < 806, 'Attendance'] = '0'  # Update attendance for employees with less than 4 hours of work

# Criteria 2: Overtime (Assuming 'Overtime' is a column indicating whether an employee worked overtime)
# Let's assume that employees who worked overtime are more likely to be absent the following day
#df.loc[df['OverTime'] == 'Yes', 'Attendance'] = '1'  # Update attendance for employees who worked overtime
#df.loc[df['JobSatisfaction'] < 3, 'Attendance'] = '0'
# Assume that if any of the following conditions are met, then attendance is 'Yes':
# 1. Employee worked overtime
# 2. Employee has high total working years (e.g., > 10)
# 3. Employee has high years at the company (e.g., > 5)
# 4. Employee has high years in current role (e.g., > 2)
#df.loc[(df['TotalWorkingYears'] > 10) |
      # (df['YearsAtCompany'] > 5) |
      # (df['YearsInCurrentRole'] > 2), 'Attendance'] = '1'

# %%
'''import pandas as pd

# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'

# Define thresholds for job involvement and satisfaction categories (adjust as needed)
#involvement_threshold = 3
satisfaction_threshold = 3

# Create a new 'Attendance' column with initial value 'NA'
df['Attendance'] = 'NA'

# Iterate through each row of the dataframe
for index, row in df.iterrows():
  # Check conditions and assign attendance category
  #high_involvement = row['JobInvolvement'] >= involvement_threshold
  high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold
  low_overtime = row['OverTime'] == 'No'

  # Define attendance categories based on combinations
  if  high_satisfaction and low_overtime:
      attendance_category = '4'
  elif  not high_satisfaction and low_overtime:
      attendance_category = '3'
  elif high_satisfaction and not low_overtime:  # Average attendance if low overtime but not high on both factors
      attendance_category = '2'
  elif not high_satisfaction and not low_overtime:  # Poor attendance if high overtime
      attendance_category = '1'

  # Update the 'Attendance' column for the current row
  df.loc[index, 'Attendance'] = attendance_category

# Now the 'df' dataframe has a new 'Attendance' column with values assigned based on the rules
'''
# Out:
# "import pandas as pd\n\n# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'\n\n# Define thresholds for job involvement and satisfaction categories (adjust as needed)\n#involvement_threshold = 3\nsatisfaction_threshold = 3\n\n# Create a new 'Attendance' column with initial value 'NA'\ndf['Attendance'] = 'NA'\n\n# Iterate through each row of the dataframe\nfor index, row in df.iterrows():\n  # Check conditions and assign attendance category\n  #high_involvement = row['JobInvolvement'] >= involvement_threshold\n  high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold\n  low_overtime = row['OverTime'] == 'No'\n\n  # Define attendance categories based on combinations\n  if  high_satisfaction and low_overtime:\n      attendance_category = '4'\n  elif  not high_satisfaction and low_overtime:\n      attendance_category = '3'\n  elif high_satisfaction and not low_overtime:  # Average attendance if low overtime but not high on both factors\n  
# ...

# %%
'''import pandas as pd

# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'

# Define thresholds for job involvement and satisfaction categories (adjust as needed)
#involvement_threshold = 3
WorkLifeBalance_threshold = 3

# Create a new 'Attendance' column with initial value 'NA'
df['Attendance'] = 'NA'

# Iterate through each row of the dataframe
for index, row in df.iterrows():
  # Check conditions and assign attendance category
  #high_involvement = row['JobInvolvement'] >= involvement_threshold
  high_WorkLifeBalance = row['WorkLifeBalance'] >= WorkLifeBalance_threshold
  low_overtime = row['OverTime'] == 'No'

  # Define attendance categories based on combinations
  if  high_WorkLifeBalance and low_overtime:
      attendance_category = '4'
  elif  not high_WorkLifeBalance and low_overtime:
      attendance_category = '3'
  elif high_WorkLifeBalance and not low_overtime:  # Average attendance if low overtime but not high on both factors
      attendance_category = '2'
  elif not high_WorkLifeBalance and not low_overtime:  # Poor attendance if high overtime
      attendance_category = '1'

  # Update the 'Attendance' column for the current row
  df.loc[index, 'Attendance'] = attendance_category

# Now the 'df' dataframe has a new 'Attendance' column with values assigned based on the rules
'''
# Out:
# "import pandas as pd\n\n# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'\n\n# Define thresholds for job involvement and satisfaction categories (adjust as needed)\n#involvement_threshold = 3\nWorkLifeBalance_threshold = 3\n\n# Create a new 'Attendance' column with initial value 'NA'\ndf['Attendance'] = 'NA'\n\n# Iterate through each row of the dataframe\nfor index, row in df.iterrows():\n  # Check conditions and assign attendance category\n  #high_involvement = row['JobInvolvement'] >= involvement_threshold\n  high_WorkLifeBalance = row['WorkLifeBalance'] >= WorkLifeBalance_threshold\n  low_overtime = row['OverTime'] == 'No'\n\n  # Define attendance categories based on combinations\n  if  high_WorkLifeBalance and low_overtime:\n      attendance_category = '4'\n  elif  not high_WorkLifeBalance and low_overtime:\n      attendance_category = '3'\n  elif high_WorkLifeBalance and not low_overtime:  # Average attendance if low overtime but not high o
# ...

# %%
import pandas as pd

# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'

# Define thresholds for job involvement and satisfaction categories (adjust as needed)
#involvement_threshold = 3
DistanceFromHome_threshold =10
#atisfaction_threshold = 3


# Create a new 'Attendance' column with initial value 'NA'
df['Attendance'] = 'NA'

# Iterate through each row of the dataframe
for index, row in df.iterrows():
  # Check conditions and assign attendance category
  #high_involvement = row['JobInvolvement'] >= involvement_threshold
  low_DistanceFromHome = row['DistanceFromHome'] <= DistanceFromHome_threshold
  low_overtime = row['OverTime'] == 'No'
  #high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold

  # Define attendance categories based on combinations
  if  low_DistanceFromHome and low_overtime :
      attendance_category = '4'
  elif  not low_DistanceFromHome and low_overtime:
      attendance_category = '3'
  elif low_DistanceFromHome and not low_overtime:  # Average attendance if low overtime but not high on both factors
      attendance_category = '2'
  elif not low_DistanceFromHome and not low_overtime:  # Poor attendance if high overtime
      attendance_category = '1'

  # Update the 'Attendance' column for the current row
  df.loc[index, 'Attendance'] = attendance_category

# Now the 'df' dataframe has a new 'Attendance' column with values assigned based on the rules

# %%
'''# prompt: save df as csv and download it
from google.colab import files

df.to_csv('data.csv')
files.download('data.csv')'''
# Out:
# "# prompt: save df as csv and download it\nfrom google.colab import files\n\ndf.to_csv('data.csv')\nfiles.download('data.csv')"

# %%
'''import pandas as pd

# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'

# Define thresholds for job involvement and satisfaction categories (adjust as needed)
#involvement_threshold = 3
DistanceFromHome_threshold =10
#atisfaction_threshold = 3


# Create a new 'Attendance' column with initial value 'NA'
test_df['Attendance'] = 'NA'

# Iterate through each row of the dataframe
for index, row in test_df.iterrows():
  # Check conditions and assign attendance category
  #high_involvement = row['JobInvolvement'] >= involvement_threshold
  low_DistanceFromHome = row['DistanceFromHome'] <= DistanceFromHome_threshold
  low_overtime = row['OverTime'] == 'No'
  #high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold

  # Define attendance categories based on combinations
  if  low_DistanceFromHome and low_overtime :
      attendance_category = '4'
  elif  not low_DistanceFromHome and low_overtime:
      attendance_category = '3'
  elif low_DistanceFromHome and not low_overtime:  # Average attendance if low overtime but not high on both factors
      attendance_category = '2'
  elif not low_DistanceFromHome and not low_overtime:  # Poor attendance if high overtime
      attendance_category = '1'

  # Update the 'Attendance' column for the current row
  test_df.loc[index, 'Attendance'] = attendance_category

# Now the 'df' dataframe has a new 'Attendance' column with values assigned based on the rules'''
# Out:
# "import pandas as pd\n\n# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'\n\n# Define thresholds for job involvement and satisfaction categories (adjust as needed)\n#involvement_threshold = 3\nDistanceFromHome_threshold =10\n#atisfaction_threshold = 3\n\n\n# Create a new 'Attendance' column with initial value 'NA'\ntest_df['Attendance'] = 'NA'\n\n# Iterate through each row of the dataframe\nfor index, row in test_df.iterrows():\n  # Check conditions and assign attendance category\n  #high_involvement = row['JobInvolvement'] >= involvement_threshold\n  low_DistanceFromHome = row['DistanceFromHome'] <= DistanceFromHome_threshold\n  low_overtime = row['OverTime'] == 'No'\n  #high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold\n\n  # Define attendance categories based on combinations\n  if  low_DistanceFromHome and low_overtime :\n      attendance_category = '4'\n  elif  not low_DistanceFromHome and low_overtime:\n      attendance_c
# ...

# %%
'''import pandas as pd

# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'

# Define thresholds for job involvement and satisfaction categories (adjust as needed)
#involvement_threshold = 3
DistanceFromHome_threshold =10
satisfaction_threshold = 3


# Create a new 'Attendance' column with initial value 'NA'
df['Attendance'] = 'NA'

# Iterate through each row of the dataframe
for index, row in df.iterrows():
  # Check conditions and assign attendance category
  #high_involvement = row['JobInvolvement'] >= involvement_threshold
  low_DistanceFromHome = row['DistanceFromHome'] <= DistanceFromHome_threshold
  low_overtime = row['OverTime'] == 'No'
  high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold

  # Define attendance categories based on combinations
  if  low_DistanceFromHome :
      attendance_category = '2'
  elif  not low_DistanceFromHome :
      attendance_category = '1'
  #elif low_DistanceFromHome :  # Average attendance if low overtime but not high on both factors
      #attendance_category = '2'
  #elif not low_DistanceFromHome :  # Poor attendance if high overtime
     # attendance_category = '1'

  # Update the 'Attendance' column for the current row
  df.loc[index, 'Attendance'] = attendance_category

# Now the 'df' dataframe has a new 'Attendance' column with values assigned based on the rules
'''
# Out:
# "import pandas as pd\n\n# Assuming you have loaded the IBM Attrition Dataset into a Pandas dataframe called 'df'\n\n# Define thresholds for job involvement and satisfaction categories (adjust as needed)\n#involvement_threshold = 3\nDistanceFromHome_threshold =10\nsatisfaction_threshold = 3\n\n\n# Create a new 'Attendance' column with initial value 'NA'\ndf['Attendance'] = 'NA'\n\n# Iterate through each row of the dataframe\nfor index, row in df.iterrows():\n  # Check conditions and assign attendance category\n  #high_involvement = row['JobInvolvement'] >= involvement_threshold\n  low_DistanceFromHome = row['DistanceFromHome'] <= DistanceFromHome_threshold\n  low_overtime = row['OverTime'] == 'No'\n  high_satisfaction = row['JobSatisfaction'] >= satisfaction_threshold\n\n  # Define attendance categories based on combinations\n  if  low_DistanceFromHome :\n      attendance_category = '2'\n  elif  not low_DistanceFromHome :\n      attendance_category = '1'\n  #elif low_DistanceFromHome 
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.shape
# Out:
# (1470, 36)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.shape
# Out:
# (1470, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
df['EmployeeCount'].unique()
df['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#df.drop(['EmployeeNumber'], axis=1, inplace=True)

# %%
df['DailyRate'].plot(kind='box')
plt.show()

# %%
df['DistanceFromHome'] = df['DistanceFromHome'].astype(int)

# %%
df['DistanceFromHome'].plot(kind='box')
plt.show()

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].astype(int)
df['MonthlyIncome'].plot(kind='box')
plt.show()

# %%
iqr = df["MonthlyIncome"].quantile(0.75) - df["MonthlyIncome"].quantile(0.25)
q1 = df["MonthlyIncome"].quantile(0.25)
q3 = df["MonthlyIncome"].quantile(0.75)

  # filter out the outliers
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["MonthlyIncome"].quantile(0.75) - df["MonthlyIncome"].quantile(0.25)
q1 = df["MonthlyIncome"].quantile(0.25)
q3 = df["MonthlyIncome"].quantile(0.75)

  # filter out the outliers
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["MonthlyIncome"].quantile(0.75) - df["MonthlyIncome"].quantile(0.25)
q1 = df["MonthlyIncome"].quantile(0.25)
q3 = df["MonthlyIncome"].quantile(0.75)

  # filter out the outliers
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["MonthlyIncome"].quantile(0.75) - df["MonthlyIncome"].quantile(0.25)
q1 = df["MonthlyIncome"].quantile(0.25)
q3 = df["MonthlyIncome"].quantile(0.75)

  # filter out the outliers
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["MonthlyIncome"].quantile(0.75) - df["MonthlyIncome"].quantile(0.25)
q1 = df["MonthlyIncome"].quantile(0.25)
q3 = df["MonthlyIncome"].quantile(0.75)

  # filter out the outliers
df = df[(df["MonthlyIncome"] > (q1 - 1.5 * iqr)) & (df["MonthlyIncome"] < (q3 + 1.5 * iqr))]

# %%
df['MonthlyIncome'].plot(kind='box')
plt.show()

# %%
df.shape
# Out:
# (1263, 36)

# %%
df['MonthlyRate'].plot(kind='box')
plt.show()

# %%
df['NumCompaniesWorked'].plot(kind='box')
plt.show()

# %%
iqr = df["NumCompaniesWorked"].quantile(0.75) - df["NumCompaniesWorked"].quantile(0.25)
q1 = df["NumCompaniesWorked"].quantile(0.25)
q3 = df["NumCompaniesWorked"].quantile(0.75)

  # filter out the outliers
df = df[(df["NumCompaniesWorked"] > (q1 - 1.5 * iqr)) & (df["NumCompaniesWorked"] < (q3 + 1.5 * iqr))]

# %%
df['NumCompaniesWorked'].plot(kind='box')
plt.show()

# %%
df['PercentSalaryHike'] = df['PercentSalaryHike'].astype(int)

df['PercentSalaryHike'].plot(kind='box')
plt.show()

# %%
iqr = df["PercentSalaryHike"].quantile(0.75) - df["PercentSalaryHike"].quantile(0.25)
q1 = df["PercentSalaryHike"].quantile(0.25)
q3 = df["PercentSalaryHike"].quantile(0.75)

  # filter out the outliers
df = df[(df["PercentSalaryHike"] > (q1 - 1.5 * iqr)) & (df["PercentSalaryHike"] < (q3 + 1.5 * iqr))]

# %%
df['TotalWorkingYears'].plot(kind='box')
plt.show()

# %%
iqr = df["TotalWorkingYears"].quantile(0.75) - df["TotalWorkingYears"].quantile(0.25)
q1 = df["TotalWorkingYears"].quantile(0.25)
q3 = df["TotalWorkingYears"].quantile(0.75)

  # filter out the outliers
df = df[(df["TotalWorkingYears"] > (q1 - 1.5 * iqr)) & (df["TotalWorkingYears"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["TotalWorkingYears"].quantile(0.75) - df["TotalWorkingYears"].quantile(0.25)
q1 = df["TotalWorkingYears"].quantile(0.25)
q3 = df["TotalWorkingYears"].quantile(0.75)

  # filter out the outliers
df = df[(df["TotalWorkingYears"] > (q1 - 1.5 * iqr)) & (df["TotalWorkingYears"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["TotalWorkingYears"].quantile(0.75) - df["TotalWorkingYears"].quantile(0.25)
q1 = df["TotalWorkingYears"].quantile(0.25)
q3 = df["TotalWorkingYears"].quantile(0.75)

  # filter out the outliers
df = df[(df["TotalWorkingYears"] > (q1 - 1.5 * iqr)) & (df["TotalWorkingYears"] < (q3 + 1.5 * iqr))]

# %%
df['TotalWorkingYears'].plot(kind='box')
plt.show()

# %%
df['TrainingTimesLastYear'].plot(kind='box')
plt.show()

# %%
iqr = df["TrainingTimesLastYear"].quantile(0.75) - df["TrainingTimesLastYear"].quantile(0.25)
q1 = df["TrainingTimesLastYear"].quantile(0.25)
q3 = df["TrainingTimesLastYear"].quantile(0.75)

  # filter out the outliers
df = df[(df["TrainingTimesLastYear"] > (q1 - 1.5 * iqr)) & (df["TrainingTimesLastYear"] < (q3 + 1.5 * iqr))]

# %%
df['TrainingTimesLastYear'].plot(kind='box')
plt.show()

# %%
df['YearsInCurrentRole'].plot(kind='box')
plt.show()

# %%
iqr = df["YearsInCurrentRole"].quantile(0.75) - df["YearsInCurrentRole"].quantile(0.25)
q1 = df["YearsInCurrentRole"].quantile(0.25)
q3 = df["YearsInCurrentRole"].quantile(0.75)

  # filter out the outliers
df = df[(df["YearsInCurrentRole"] > (q1 - 1.5 * iqr)) & (df["YearsInCurrentRole"] < (q3 + 1.5 * iqr))]

# %%
df['YearsInCurrentRole'].plot(kind='box')
plt.show()

# %%
df['YearsSinceLastPromotion'].plot(kind='box')
plt.show()

# %%
iqr = df["YearsSinceLastPromotion"].quantile(0.75) - df["YearsSinceLastPromotion"].quantile(0.25)
q1 = df["YearsSinceLastPromotion"].quantile(0.25)
q3 = df["YearsSinceLastPromotion"].quantile(0.75)

  # filter out the outliers
df = df[(df["YearsSinceLastPromotion"] > (q1 - 1.5 * iqr)) & (df["YearsSinceLastPromotion"] < (q3 + 1.5 * iqr))]

# %%
iqr = df["YearsSinceLastPromotion"].quantile(0.75) - df["YearsSinceLastPromotion"].quantile(0.25)
q1 = df["YearsSinceLastPromotion"].quantile(0.25)
q3 = df["YearsSinceLastPromotion"].quantile(0.75)

  # filter out the outliers
df = df[(df["YearsSinceLastPromotion"] > (q1 - 1.5 * iqr)) & (df["YearsSinceLastPromotion"] < (q3 + 1.5 * iqr))]

# %%
df['YearsSinceLastPromotion'].plot(kind='box')
plt.show()

# %%
df['YearsWithCurrManager'].plot(kind='box')
plt.show()

# %%
iqr = df["YearsWithCurrManager"].quantile(0.75) - df["YearsWithCurrManager"].quantile(0.25)
q1 = df["YearsWithCurrManager"].quantile(0.25)
q3 = df["YearsWithCurrManager"].quantile(0.75)

  # filter out the outliers
df = df[(df["YearsWithCurrManager"] > (q1 - 1.5 * iqr)) & (df["YearsWithCurrManager"] < (q3 + 1.5 * iqr))]

# %%
df['YearsWithCurrManager'].plot(kind='box')
plt.show()

# %%
df['HourlyRate'] = df['HourlyRate'].astype(int)
df['HourlyRate'].plot(kind='box')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 707 entries, 1 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       707 non-null    int64
#  1   Attrition                 707 non-null    object
#  2   BusinessTravel            707 non-null    object
#  3   DailyRate                 707 non-null    int64
#  4   Department                707 non-null    object
#  5   DistanceFromHome          707 non-null    int64
#  6   Education                 707 non-null    int64
#  7   EducationField            707 non-null    object
#  8   EmployeeCount             707 non-null    int64
#  9   EmployeeNumber            707 non-null    int64
#  10  EnvironmentSatisfaction   707 non-null    int64
#  11  Gender                    707 non-null    object
#  12  HourlyRate                707 non-null    int64
#  13  JobInvolvement            707 non-null    int64
# ...

# %%
df1 = df.copy()

# %%
df2= df.copy()

# %%
df['EmployeeCount'] = df['EmployeeCount'].astype(int)
df2['EmployeeCount'] = df2['EmployeeCount'].astype(int)

# %%
import plotly.express as px
rate_att=df2.groupby(['MonthlyIncome','Attrition']).apply(lambda x:x['MonthlyIncome'].count()).reset_index(name='Counts')
rate_att['MonthlyIncome']=round(rate_att['MonthlyIncome'],-3)
rate_att=rate_att.groupby(['MonthlyIncome','Attrition']).apply(lambda x:x['MonthlyIncome'].count()).reset_index(name='Counts')
fig=px.line(rate_att,x='MonthlyIncome',y='Counts',color='Attrition',title='Monthly Income basis counts of People in an Organization')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
JobRole_att=df2.groupby(['JobRole','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
fig=px.bar(JobRole_att,x='JobRole',y='Counts',color='Attrition',title='JobRole wise Counts of People in an Organization')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsAtCompany=df2.groupby(['YearsAtCompany','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsAtCompany,x='YearsAtCompany',y='Counts',color='Attrition',title='YearsAtCompany Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsSinceLastPromotion=df2.groupby(['YearsSinceLastPromotion','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsSinceLastPromotion,x='YearsSinceLastPromotion',y='Counts',color='Attrition',title='YearsSinceLastPromotion Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsInCurrentRole=df2.groupby(['YearsInCurrentRole','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsInCurrentRole,x='YearsInCurrentRole',y='Counts',color='Attrition',title='YearsInCurrentRole Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
YearsWithCurrManager=df2.groupby(['YearsWithCurrManager','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(YearsWithCurrManager,x='YearsWithCurrManager',y='Counts',color='Attrition',title='YearsWithCurrManager Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
TotalWorkingYears=df2.groupby(['TotalWorkingYears','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(TotalWorkingYears,x='TotalWorkingYears',y='Counts',color='Attrition',title='TotalWorkingYears Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
EnvironmentSatisfaction=df2.groupby(['EnvironmentSatisfaction','Attrition']).apply(lambda x:x['DailyRate'].count()).reset_index(name='Counts')
px.line(EnvironmentSatisfaction,x='EnvironmentSatisfaction',y='Counts',color='Attrition',title='EnvironmentSatisfaction Counts of People in an Organization')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df2['BusinessTravel']=label_encoder.fit_transform(df2['BusinessTravel'])
df2['Department']=label_encoder.fit_transform(df2['Department'])
df2['EducationField']=label_encoder.fit_transform(df2['EducationField'])
df2['Gender']=label_encoder.fit_transform(df2['Gender'])
df2['JobRole']=label_encoder.fit_transform(df2['JobRole'])
df2['JobSatisfaction']=label_encoder.fit_transform(df2['JobSatisfaction'])
df2['MaritalStatus']=label_encoder.fit_transform(df2['MaritalStatus'])
df2['Over18']=label_encoder.fit_transform(df2['Over18'])
df2['OverTime']=label_encoder.fit_transform(df2['OverTime'])

# %%
df2
# Out:
#       Age Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 1      49        No               1        279           1                 8
# 2      37       Yes               2       1373           1                 2
# 6      59        No               2       1324           1                 3
# 7      30        No               2       1358           1                24
# 8      38        No               1        216           1                23
# ...   ...       ...             ...        ...         ...               ...
# 1463   31        No               0        325           1                 5
# 1464   26        No               2       1167           2                 5
# 1465   36        No               1        884           1                23
# 1468   49        No               1       1023           2                 2
# 1469   34        No               2        628           1                 8
#
# ...

# %%
'''corrMatrix = df2.corr()
fig, ax = plt.subplots(figsize=(40,40))
sns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax)'''
# Out:
# 'corrMatrix = df2.corr()\nfig, ax = plt.subplots(figsize=(40,40))\nsns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax)'

# %%
y=df2['Attrition']
X=df2.drop('Attrition',axis=1)
X.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 6   59               2       1324           1                 3          3
# 7   30               2       1358           1                24          1
# 8   38               1        216           1                23          3
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 1               1              1               2                        3
# 2               4              1               4                        4
# 6               3              1              10                        3
# 7               1              1              11                        4
# 8               1              1              12                        4
#
#    ...  StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
#test_df.isnull().sum()

# %%
'''
X_train= df.drop('Attrition',axis=1)
y_train=df['Attrition']
X_test= test_df.drop('Attrition',axis=1)
y_test=test_df['Attrition']
'''
# Out:
# "\nX_train= df.drop('Attrition',axis=1)\ny_train=df['Attrition']\nX_test= test_df.drop('Attrition',axis=1)\ny_test=test_df['Attrition']\n"

# %%
#X_test.isnull().sum()

# %% [markdown]
# ### Step 3: Split dataset into training and testing
#
# First, we need to split the data into independent and dependent features.

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=3)

print('train set:',X_train.shape)
print('test set:',X_test.shape)
# Out:
# train set: (530, 35)
# test set: (177, 35)

# %%
X_train
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1394   32               2       1373           1                 5          4
# 56     35               1        853           2                18          5
# 1249   29               2        428           2                 9          3
# 499    33               2       1216           2                 8          4
# 91     51               2        632           2                21          4
# ...   ...             ...        ...         ...               ...        ...
# 1371   56               2       1443           2                11          5
# 565    23               2        310           1                10          1
# 1343   29               2        592           1                 7          3
# 547    42               1        933           1                19          3
# 1381   28               0       1103           1                16          3
#
# ...

# %%
#X_test.isnull().sum()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# %%
gnb = GaussianNB(priors=[0.6,0.4])

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=[0.6, 0.4])

# %%
y_train_pred = gnb.predict(X_train)
y_test_pred = gnb.predict(X_test)

# %%
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print(" test Accuracy:", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  0.7320754716981132
#  test Accuracy: 0.7740112994350282

# %%
#np.logspace(0,-9, num=10)
np.logspace(-1, 1, num=100)
# Out:
# array([ 0.1       ,  0.10476158,  0.10974988,  0.1149757 ,  0.12045035,
#         0.12618569,  0.13219411,  0.13848864,  0.14508288,  0.15199111,
#         0.15922828,  0.16681005,  0.17475284,  0.18307383,  0.19179103,
#         0.2009233 ,  0.21049041,  0.22051307,  0.23101297,  0.24201283,
#         0.25353645,  0.26560878,  0.27825594,  0.29150531,  0.30538555,
#         0.31992671,  0.33516027,  0.35111917,  0.36783798,  0.38535286,
#         0.40370173,  0.42292429,  0.44306215,  0.46415888,  0.48626016,
#         0.5094138 ,  0.53366992,  0.55908102,  0.58570208,  0.61359073,
#         0.64280731,  0.67341507,  0.70548023,  0.7390722 ,  0.77426368,
#         0.81113083,  0.84975344,  0.89021509,  0.93260335,  0.97700996,
#         1.02353102,  1.07226722,  1.12332403,  1.17681195,  1.23284674,
#         1.29154967,  1.35304777,  1.41747416,  1.48496826,  1.55567614,
#         1.62975083,  1.70735265,  1.78864953,  1.87381742,  1.96304065,
# ...

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

cv_method = RepeatedStratifiedKFold(n_splits=5,
                                    n_repeats=3,
                                    random_state=999)

# %%
X_train.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
from sklearn.preprocessing import PowerTransformer
import sklearn.preprocessing

#from sklearn.preprocessing import BoxCoxTransformer
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=gnb,
                     param_grid=params_NB,
                     cv=cv_method,
                     verbose=1,
                     scoring='accuracy')

'''sklearn.preprocessing.power_transform(X, method='box-cox',  standardize=True, copy=True)
Data_transformed_train = BoxCoxTransformer().fit_transform(X_train)
Data_transformed_test = BoxCoxTransformer().fit_transform(X_test)'''
import sklearn.preprocessing
#from sklearn.preprocessing import BoxCoxTransformer

#Data_transformed_train = BoxCoxTransformer().fit_transform(X_train)

Data_transformed_train = PowerTransformer().fit_transform(X_train)
Data_transformed_test = PowerTransformer().fit_transform(X_test)
#Data_transformed_train = X_train
#Data_transformed_test = X_test

# %%
gs_NB.fit(Data_transformed_train, y_train);
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 1.0}

# %%
gs_NB.best_score_
# Out:
# 0.8006289308176101

# %%
best_gnb = gs_NB.best_estimator_

# %%
best_gnb.fit(Data_transformed_train, y_train);

# %%
# predict the target on the test dataset
predict_train = best_gnb.predict(Data_transformed_train)
predict_test = best_gnb.predict(Data_transformed_test)


# Accuracy Score on test dataset
accuracy_train = metrics.accuracy_score(y_train,predict_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)


print('accuracy_score on train dataset : ', accuracy_train)
print('accuracy_score on test dataset : '
, accuracy_test)
# Out:
# accuracy_score on train dataset :  0.8132075471698114
# accuracy_score on test dataset :  0.8192090395480226

# %%
# The mean of each feature per class
means = best_gnb.theta_

# The variance of each feature per class
variances = best_gnb.var_

# Calculate the absolute difference in means between classes for each feature
mean_diffs = np.abs(means[1] - means[0])

# Optionally, you can normalize these differences by the variances to give more weight to features with lower variance
normalized_diffs = mean_diffs / np.sqrt(variances).mean(axis=0)

# Now you have a basic measure of feature importance
feature_importance = normalized_diffs

# Assuming X has column names
feature_names = X.columns

# Sorting features by importance
sorted_idx = np.argsort(feature_importance)[::-1]
sorted_features = feature_names[sorted_idx]
sorted_importances = feature_importance[sorted_idx]

# Displaying features and their approximate importance
for feature, importance in zip(sorted_features, sorted_importances):
    print(f"{feature}: {importance}")
# Out:
# StockOptionLevel: 0.4286088646103907
# YearsAtCompany: 0.41543665916976985
# YearsInCurrentRole: 0.39166023227177316
# MonthlyIncome: 0.37319174436255464
# Attendance: 0.3719099146644171
# OverTime: 0.36857258339619065
# YearsWithCurrManager: 0.36245505065364786
# JobLevel: 0.34482545992745156
# JobSatisfaction: 0.33710850081106064
# EnvironmentSatisfaction: 0.3369556077535075
# TotalWorkingYears: 0.3341364262233326
# Age: 0.3094374684744589
# MaritalStatus: 0.27644085009161384
# JobInvolvement: 0.2650985860084187
# PercentSalaryHike: 0.17823658620310104
# RelationshipSatisfaction: 0.1521242241772127
# Department: 0.12663154014378677
# DailyRate: 0.11953086273509811
# WorkLifeBalance: 0.11390766980207552
# YearsSinceLastPromotion: 0.11311441595679621
# DistanceFromHome: 0.10437126767663747
# JobRole: 0.08874736279612863
# NumCompaniesWorked: 0.08819294383895984
# EducationField: 0.05590278172589058
# Education: 0.048327352407889455
# EmployeeNumber: 0.03634455834002152
# ...

# %%
import matplotlib.pyplot as plt

# Ensure sorted_features and sorted_importances are available
# For demonstration, let's assume these are your features and importances
# sorted_features = ['feature1', 'feature2', 'feature3', ...]
# sorted_importances = [0.25, 0.15, 0.10, ...]

# Plotting
plt.figure(figsize=(10, 8))
plt.barh(range(len(sorted_importances)), sorted_importances, align='center')
plt.yticks(range(len(sorted_importances)), sorted_features)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances for Gaussian Naive Bayes Model')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()

# %%
X_train
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1394   32               2       1373           1                 5          4
# 56     35               1        853           2                18          5
# 1249   29               2        428           2                 9          3
# 499    33               2       1216           2                 8          4
# 91     51               2        632           2                21          4
# ...   ...             ...        ...         ...               ...        ...
# 1371   56               2       1443           2                11          5
# 565    23               2        310           1                10          1
# 1343   29               2        592           1                 7          3
# 547    42               1        933           1                19          3
# 1381   28               0       1103           1                16          3
#
# ...

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import os
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime as dt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.callbacks import EarlyStopping
from keras.layers import Activation

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import KFold
from statistics import mean

from mlxtend.frequent_patterns import apriori, association_rules

import warnings
warnings.filterwarnings("ignore")

# %%
mlp = MLPClassifier()

# %%
from sklearn.model_selection import GridSearchCV
# Define the hyperparameters to tune
param_grid = {
    'solver': ['adam', 'sgd'],
    'activation': ['relu','logistic'],
   'hidden_layer_sizes':[90,100,104,105,120],
    'max_iter':[90,100,104,105,120],
    'alpha':[0.01,0.02,0.05]
}

# Perform GridSearchCV to find the best hyperparameters
grid = GridSearchCV(estimator=mlp, param_grid=param_grid, cv=5)
grid_result = grid.fit(X_train, y_train)

# Print the best hyperparameters and accuracy
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.813208 using {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': 100, 'max_iter': 100, 'solver': 'sgd'}

# %%
mlp = MLPClassifier(alpha= 0.05, hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=120)

# %%
from sklearn import metrics
mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print('Accuracy Score on test data: ', metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  0.7433962264150943
# Accuracy Score on test data:  0.6949152542372882

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = mlp.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.78      0.83      0.81       136
#          Yes       0.30      0.24      0.27        41
#
#     accuracy                           0.69       177
#    macro avg       0.54      0.54      0.54       177
# weighted avg       0.67      0.69      0.68       177

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[113  23]
#  [ 31  10]]

# %%
cm = confusion_matrix(y_test,predictions)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of MLP (Multi-layer Perceptron)')
plt.show()

# %%
def LSTM_model():
    """
    Create and configure an LSTM model for stock price prediction.

    :return: The configured LSTM model (keras.Sequential)
    """

    # Initialize a sequential model
    model = Sequential()

    # Add the first LSTM layer with 50 units, input shape, and return sequences
    model.add(LSTM(units=14, return_sequences=True, input_shape=(new_X_train.shape[1], 1)))
    # Add dropout to prevent overfitting
    model.add(Dropout(0.2))

    # Add a second LSTM layer with 50 units and return sequences
    model.add(LSTM(units=21, return_sequences=True))
    # Add dropout to prevent overfitting
    model.add(Dropout(0.2))


    # Add a dense output layer with one unit
    model.add(Dense(units=1))

    return model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# Build the B-LSTM model
model = tf.keras.Sequential([
    # Input layer
tf.keras.layers.InputLayer((X_train.shape[1], 1)),

    # Hidden layer with ReLU activation
tf.keras.layers.Dense(21, activation='relu'),

    # Output layer with Sigmoid activation for binary classification
tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Assuming you have input features X and labels y
# Build the BI-LSTM model
model1 = Sequential([
    Bidirectional(LSTM(21, activation='relu'), input_shape=(X_train.shape[1], 1)),
    Dense(1, activation='sigmoid')
])

# %%
int_y_train=label_encoder.fit_transform(y_train)

# %%
y_train_float = int_y_train.astype(np.float32)
new_X_train_float = X_train.astype(np.float32)

# %%
# Compile the model
model1.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
# Train the model
model1.fit(new_X_train_float, y_train_float, epochs=170, batch_size=32)
# Out:
# Epoch 1/170
# 17/17 [==============================] - 4s 19ms/step - loss: 0.3050 - accuracy: 0.6849
# Epoch 2/170
# 17/17 [==============================] - 0s 20ms/step - loss: 0.2159 - accuracy: 0.7830
# Epoch 3/170
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2170 - accuracy: 0.7830
# Epoch 4/170
# 17/17 [==============================] - 0s 21ms/step - loss: 0.2067 - accuracy: 0.7925
# Epoch 5/170
# 17/17 [==============================] - 0s 21ms/step - loss: 0.2376 - accuracy: 0.7623
# Epoch 6/170
# 17/17 [==============================] - 0s 18ms/step - loss: 0.2446 - accuracy: 0.7547
# Epoch 7/170
# 17/17 [==============================] - 0s 29ms/step - loss: 0.2001 - accuracy: 0.8000
# Epoch 8/170
# 17/17 [==============================] - 0s 23ms/step - loss: 0.2194 - accuracy: 0.7792
# Epoch 9/170
# 17/17 [==============================] - 0s 21ms/step - loss: 0.2234 - accuracy: 0.7755
# Epoch 10/170
# ...

# %%
int_y_test=label_encoder.fit_transform(y_test)
y_test_float = int_y_test.astype(np.float32)

# %%
new_X_test_float = X_test.astype(np.float32)

# %%
# Evaluate the model on the test set
loss, accuracy = model1.evaluate(new_X_test_float, y_test_float)
print(f'Binary Crossentropy Loss on Test Data: {loss}')
print(f'Accuracy on Test Data: {accuracy}')
# Out:
# 6/6 [==============================] - 1s 7ms/step - loss: 0.2429 - accuracy: 0.7571
# Binary Crossentropy Loss on Test Data: 0.2429378479719162
# Accuracy on Test Data: 0.7570621371269226

# %%
predictions2 = model1.predict(new_X_test_float)
binary_predictions2 = (predictions2 > 0.5).astype(int)
# Out:
# 6/6 [==============================] - 0s 8ms/step

# %%
cm = confusion_matrix(y_test_float,binary_predictions2)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of LSTM')

plt.show()

# %%
# Define the KNN model
from sklearn.model_selection import GridSearchCV
knn = KNeighborsClassifier()

# Define the hyperparameters to search
param_grid = {'n_neighbors': [1, 3, 5, 7, 9,10,12,26,20,25,30]}

# Create the grid search object
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, scoring='accuracy', cv=10)

# Perform the grid search on the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters found
print("Best Hyperparameters:", grid_search.best_params_)

# Get the best model
best_knn = grid_search.best_estimator_
# Out:
# Best Hyperparameters: {'n_neighbors': 12}

# %%
from sklearn import metrics
knn = KNeighborsClassifier(n_neighbors= 12)
knn.fit(X_train,y_train)
y_train_pred3 = knn.predict(X_train)
y_test_pred3 = knn.predict(X_test)
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred3))
print('Accuracy Score on test data: ', metrics.accuracy_score(y_test, y_test_pred3))
# Out:
# Accuracy Score on train data:  0.8132075471698114
# Accuracy Score on test data:  0.7627118644067796

# %%
predictions4 = knn.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions4))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.77      0.99      0.87       136
#          Yes       0.00      0.00      0.00        41
#
#     accuracy                           0.76       177
#    macro avg       0.38      0.50      0.43       177
# weighted avg       0.59      0.76      0.66       177

# %%
cm = confusion_matrix(y_test,predictions4)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of KNN')
plt.show()

# %%
LR=LogisticRegression()
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = LR.predict(X_train)

# %%
y_pred_test = LR.predict(X_test)

# %%
print("The classification report \n")
print(classification_report(y_test,y_pred_test))
# Out:
# The classification report
#
#               precision    recall  f1-score   support
#
#           No       0.82      0.99      0.90       136
#          Yes       0.92      0.27      0.42        41
#
#     accuracy                           0.82       177
#    macro avg       0.87      0.63      0.66       177
# weighted avg       0.84      0.82      0.79       177

# %%
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train,y_pred_train))
print("LR test Accuracy:", metrics.accuracy_score(y_test,y_pred_test))
# Out:
# Accuracy Score on train data:  0.8188679245283019
# LR test Accuracy: 0.8248587570621468

# %%
from sklearn.metrics import confusion_matrix
cm = (confusion_matrix(y_test,y_pred_test))
cmdf = pd.DataFrame(cm,index=['B','M'], columns=['B','M'])
print("The confusion matrix looks like following...\n")
cmdf
# Out:
# The confusion matrix looks like following...
#      B   M
# B  135   1
# M   30  11

# %%
cm = confusion_matrix(y_test,y_pred_test)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of Logistic Regression')
plt.show()

# %%
# prompt: naive bayes

from sklearn.naive_bayes import GaussianNB

# Define the Gaussian Naive Bayes model
gnb = GaussianNB()

# Train the model using the training data
gnb.fit(X_train, y_train)

y_pred_gnb_train = gnb.predict(X_train)

# Evaluate the accuracy of the model
accuracy_gnb_train = accuracy_score(y_train, y_pred_gnb_train)

# Print the accuracy
print("Accuracy of the Naive Bayes model train:", accuracy_gnb_train)


# Predict the labels for the test data
y_pred_gnb_test = gnb.predict(X_test)

# Evaluate the accuracy of the model
accuracy_gnb_test = accuracy_score(y_test, y_pred_gnb_test)

# Print the accuracy
print("Accuracy of the Naive Bayes model test:", accuracy_gnb_test)
# Out:
# Accuracy of the Naive Bayes model train: 0.8132075471698114
# Accuracy of the Naive Bayes model test: 0.8248587570621468

# %%
print("The classification report \n")
print(classification_report(y_test,y_pred_gnb_test))
# Out:
# The classification report
#
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       136
#          Yes       0.63      0.59      0.61        41
#
#     accuracy                           0.82       177
#    macro avg       0.75      0.74      0.75       177
# weighted avg       0.82      0.82      0.82       177

# %%
cm = confusion_matrix(y_test,y_pred_gnb_test)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of Gaussian Naive Bayes')
plt.show()

# %% [markdown]
# ### Step 4: Train and test Decision-Tree classifier using the Scikit-Learn library
#
# We will import the DecisionTreeClassifier function from the Scikit-Learn library. We will first build a decision tree with default parameters to get a baseline idea of the performance

# %%
#Importing the Decision tree classifier from the scikit-learn library.
clf_dt = tree.DecisionTreeClassifier(random_state=40)

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=40)

# %%
y_train_pred = clf_dt.predict(X_train)

# %%
y_test_pred = clf_dt.predict(X_test)

# %%
#Use accuracy metric from sklearn.metrics library
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print('Accuracy Score on test data: ', metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  1.0
# Accuracy Score on test data:  0.7288135593220338

# %%
max_depth = np.linspace(1,32,32,dtype='int32')
accuracy_train,accuracy_test=[],[]

for i in max_depth:
    clf_dt=tree.DecisionTreeClassifier(max_depth=i, random_state=40)
    clf_dt.fit(X_train,y_train)
    y_train_pred = clf_dt.predict(X_train)
    y_test_pred = clf_dt.predict(X_test)

    accuracy_train.append(metrics.accuracy_score(y_train, y_train_pred))
    accuracy_test.append(metrics.accuracy_score(y_test, y_test_pred))

ax= plt.figure(figsize=(10, 8))
plt.plot(max_depth,accuracy_train)
plt.plot(max_depth,accuracy_test)
plt.ylabel('Accuracy')
plt.xlabel('Tree depth')
plt.legend(['Training', 'Testing'],loc='lower right', borderpad=0, handletextpad=0)
plt.show()

# %%
min_samples_split = np.linspace(2, 50, 50,dtype='int32')
accuracy_train,accuracy_test=[],[]

for i in min_samples_split:
    clf_dt=tree.DecisionTreeClassifier(min_samples_split=i, random_state=40)
    clf_dt.fit(X_train,y_train)
    y_train_pred = clf_dt.predict(X_train)
    y_test_pred = clf_dt.predict(X_test)

    accuracy_train.append(metrics.accuracy_score(y_train, y_train_pred))
    accuracy_test.append(metrics.accuracy_score(y_test, y_test_pred))

ax= plt.figure(figsize=(10, 8))
plt.plot(min_samples_split,accuracy_train)
plt.plot(min_samples_split,accuracy_test)
plt.ylabel('Accuracy')
plt.xlabel('min_samples_splits')
plt.legend(['Training', 'Testing'],loc='upper right', borderpad=0, handletextpad=0)
plt.show()

# %%
Tuned_tree = tree.DecisionTreeClassifier(random_state=40,max_depth=4, min_samples_split=34)
Tuned_tree.fit(X_train,y_train)
y_train_pred = Tuned_tree.predict(X_train)
y_test_pred = Tuned_tree.predict(X_test)

#Use accuracy metric from sklearn.metrics library
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print('Accuracy Score on test data: ', metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  0.8528301886792453
# Accuracy Score on test data:  0.8135593220338984

# %%
predictions = Tuned_tree.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.98      0.89       136
#          Yes       0.79      0.27      0.40        41
#
#     accuracy                           0.81       177
#    macro avg       0.80      0.62      0.64       177
# weighted avg       0.81      0.81      0.78       177

# %%
cm = confusion_matrix(y_test,predictions)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of Decision Tree')
plt.show()

# %% [markdown]
# ## Section 2: Random Forest
#
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and use averaging to improve the predictive accuracy and control over-fitting. We will first build a decision tree with default parameters to get a baseline idea of the performance.
#
# ### Step 1: Train and test Random Forest classifier using the Scikit-Learn library

# %%
clf=RandomForestClassifier(random_state=40)

#Train the model using the training sets
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=40)

# %%
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

# %%
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print("Random Forest test Accuracy:", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  1.0
# Random Forest test Accuracy: 0.8135593220338984

# %%
n_estimators = [1, 2, 4, 8, 16, 32, 64, 100]
accuracy_train,accuracy_test=[],[]

for i in n_estimators:
    clf_rf=RandomForestClassifier(n_estimators=i, random_state=40)
    clf_rf.fit(X_train,y_train)
    y_train_pred = clf_rf.predict(X_train)
    y_test_pred = clf_rf.predict(X_test)

    accuracy_train.append(metrics.accuracy_score(y_train, y_train_pred))
    accuracy_test.append(metrics.accuracy_score(y_test, y_test_pred))

ax= plt.figure(figsize=(10, 8))
plt.plot(n_estimators,accuracy_train)
plt.plot(n_estimators,accuracy_test)
plt.ylabel('Accuracy')
plt.xlabel('n_estimators')
plt.legend(['Training', 'Testing'],loc='upper right', borderpad=0, handletextpad=0)
plt.show()

# %%
max_depth = np.linspace(1,20,20,dtype='int32')
accuracy_train,accuracy_test=[],[]

for i in max_depth:
    clf_rf=RandomForestClassifier(max_depth=i, random_state=40)
    clf_rf.fit(X_train,y_train)
    y_train_pred = clf_rf.predict(X_train)
    y_test_pred = clf_rf.predict(X_test)

    accuracy_train.append(metrics.accuracy_score(y_train, y_train_pred))
    accuracy_test.append(metrics.accuracy_score(y_test, y_test_pred))

ax= plt.figure(figsize=(10, 8))
plt.plot(max_depth,accuracy_train)
plt.plot(max_depth,accuracy_test)
plt.ylabel('Accuracy')
plt.xlabel('max_depth')
plt.legend(['Training', 'Testing'],loc='upper right')
plt.show()

# %%
clf = RandomForestClassifier(n_estimators=4,max_depth=4, random_state=40)

#Train the model using the training data
clf.fit(X_train, y_train)

y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print("Random Forest test Accuracy:", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  0.8547169811320755
# Random Forest test Accuracy: 0.8022598870056498

# %%
import matplotlib.pyplot as plt

# Accuracy scores
train_accuracy = 0.8547169811320755
test_accuracy = 0.8022598870056498

# Bar plot for accuracies
labels = ['Train Accuracy', 'Test Accuracy']
accuracies = [train_accuracy, test_accuracy]

plt.figure(figsize=(8, 6))
plt.bar(labels, accuracies, color=['blue', 'green'])
plt.ylim(0, 1)
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.show()

# %%
predictions = clf.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.80      0.99      0.88       136
#          Yes       0.80      0.20      0.31        41
#
#     accuracy                           0.80       177
#    macro avg       0.80      0.59      0.60       177
# weighted avg       0.80      0.80      0.75       177

# %%
cm = confusion_matrix(y_test,predictions)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of Random Forest')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Model names
models = ['MLP', 'KNN', 'Logistic Regression', 'Decision Tree', 'Random Forest','LSTM' , 'Gaussian Naive Bayes']

# Accuracy scores on train and test data
accuracy_train = [77.36, 81.32, 81.89, 85.28, 85.47,87.35, 81.32]
accuracy_test = [72.88, 76.27, 82.49, 81.36, 80.23,77.4, 82.49]

# Recall scores for the 'Yes' class, converted to percentages
recall_yes = [0.34 * 100, 0.00 * 100, 0.27 * 100, 0.27 * 100, 0.20 * 100, 0.15*100 , 0.59 * 100]

# Set the positions of the bars on the x-axis
x = np.arange(len(models))

# Width of a bar
width = 0.25

# Create the bar chart
fig, ax = plt.subplots()

# Plot accuracy bars
bar1 = ax.bar(x - width, accuracy_train, width, label='Accuracy Train', color='b')
bar2 = ax.bar(x, accuracy_test, width, label='Accuracy Test', color='g')
bar3 = ax.bar(x + width, recall_yes, width, label='Recall (Yes)', color='r')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Models')
ax.set_ylabel('Percentage (%)')
ax.set_title('Model Performance: Accuracy and Recall (Yes)')

# Set the position of the x ticks
ax.set_xticks(x)
# Set the labels for the x ticks and rotate them
ax.set_xticklabels(models, rotation=45, ha='right')

# Add legend and move it away from the bars
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Display the chart
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import classification_report

# Generate classification report as dictionary
report = classification_report(y_test, y_test_pred, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Plotting the classification report
plt.figure(figsize=(10, 6))
sns.heatmap(df_report.iloc[:-1, :-1], annot=True, cmap='Blues', fmt='.2f')
plt.title('Classification Report')
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

# %%
gnb = GaussianNB(priors=[0.6,0.4])

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=[0.6, 0.4])

# %%
y_train_pred = gnb.predict(X_train)
y_test_pred = gnb.predict(X_test)

# %%
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print(" test Accuracy:", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  0.7320754716981132
#  test Accuracy: 0.7740112994350282

# %%
#np.logspace(0,-9, num=10)
np.logspace(-1, 1, num=100)
# Out:
# array([ 0.1       ,  0.10476158,  0.10974988,  0.1149757 ,  0.12045035,
#         0.12618569,  0.13219411,  0.13848864,  0.14508288,  0.15199111,
#         0.15922828,  0.16681005,  0.17475284,  0.18307383,  0.19179103,
#         0.2009233 ,  0.21049041,  0.22051307,  0.23101297,  0.24201283,
#         0.25353645,  0.26560878,  0.27825594,  0.29150531,  0.30538555,
#         0.31992671,  0.33516027,  0.35111917,  0.36783798,  0.38535286,
#         0.40370173,  0.42292429,  0.44306215,  0.46415888,  0.48626016,
#         0.5094138 ,  0.53366992,  0.55908102,  0.58570208,  0.61359073,
#         0.64280731,  0.67341507,  0.70548023,  0.7390722 ,  0.77426368,
#         0.81113083,  0.84975344,  0.89021509,  0.93260335,  0.97700996,
#         1.02353102,  1.07226722,  1.12332403,  1.17681195,  1.23284674,
#         1.29154967,  1.35304777,  1.41747416,  1.48496826,  1.55567614,
#         1.62975083,  1.70735265,  1.78864953,  1.87381742,  1.96304065,
# ...

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

cv_method = RepeatedStratifiedKFold(n_splits=5,
                                    n_repeats=3,
                                    random_state=999)

# %%
X_train.isnull().sum()
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
'''np.isnan(X_train).sum()'''
# Out:
# 'np.isnan(X_train).sum()'

# %%
'''np.isinf(X_train).sum()'''
# Out:
# 'np.isinf(X_train).sum()'

# %%
'''from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\nX_train_scaled = scaler.fit_transform(X_train)\nX_test_scaled = scaler.transform(X_test)'

# %%
from sklearn.preprocessing import PowerTransformer
import sklearn.preprocessing

#from sklearn.preprocessing import BoxCoxTransformer
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=gnb,
                     param_grid=params_NB,
                     cv=cv_method,
                     verbose=1,
                     scoring='accuracy')

'''sklearn.preprocessing.power_transform(X, method='box-cox',  standardize=True, copy=True)
Data_transformed_train = BoxCoxTransformer().fit_transform(X_train)
Data_transformed_test = BoxCoxTransformer().fit_transform(X_test)'''
import sklearn.preprocessing
#from sklearn.preprocessing import BoxCoxTransformer

#Data_transformed_train = BoxCoxTransformer().fit_transform(X_train)

Data_transformed_train = PowerTransformer().fit_transform(X_train)
Data_transformed_test = PowerTransformer().fit_transform(X_test)
#Data_transformed_train = X_train
#Data_transformed_test = X_test

# %%
gs_NB.fit(Data_transformed_train, y_train);
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 1.0}

# %%
gs_NB.best_score_
# Out:
# 0.8006289308176101

# %%
best_gnb = gs_NB.best_estimator_

# %%
best_gnb.fit(Data_transformed_train, y_train);

# %%
'''y_test = np.where(y_test == 'Yes', 1, 0)'''
# Out:
# "y_test = np.where(y_test == 'Yes', 1, 0)"

# %%
'''import numpy as np
from sklearn.metrics import precision_recall_curve

# Assuming 'model' is your trained Naive Bayes model and X_test is your test data
probabilities = best_gnb.predict_proba(X_test)[:, 1]  # probabilities for the positive class
precision, recall, thresholds = precision_recall_curve(y_test, probabilities)

# Choose a threshold that gives you a higher recall
threshold = thresholds[np.argmax(recall >= 0.70)]  # for example, to achieve at least 90% recall
predicted = (probabilities >= threshold).astype(int)
'''
# Out:
# "import numpy as np\nfrom sklearn.metrics import precision_recall_curve\n\n# Assuming 'model' is your trained Naive Bayes model and X_test is your test data\nprobabilities = best_gnb.predict_proba(X_test)[:, 1]  # probabilities for the positive class\nprecision, recall, thresholds = precision_recall_curve(y_test, probabilities)\n\n# Choose a threshold that gives you a higher recall\nthreshold = thresholds[np.argmax(recall >= 0.70)]  # for example, to achieve at least 90% recall\npredicted = (probabilities >= threshold).astype(int)\n"

# %%
# predict the target on the test dataset
predict_train = best_gnb.predict(Data_transformed_train)
predict_test = best_gnb.predict(Data_transformed_test)


# Accuracy Score on test dataset
accuracy_train = metrics.accuracy_score(y_train,predict_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)


print('accuracy_score on train dataset : ', accuracy_train)
print('accuracy_score on test dataset : '
, accuracy_test)
# Out:
# accuracy_score on train dataset :  0.8132075471698114
# accuracy_score on test dataset :  0.8192090395480226

# %%
# The mean of each feature per class
means = best_gnb.theta_

# The variance of each feature per class
variances = best_gnb.var_

# Calculate the absolute difference in means between classes for each feature
mean_diffs = np.abs(means[1] - means[0])

# Optionally, you can normalize these differences by the variances to give more weight to features with lower variance
normalized_diffs = mean_diffs / np.sqrt(variances).mean(axis=0)

# Now you have a basic measure of feature importance
feature_importance = normalized_diffs

# Assuming X has column names
feature_names = X.columns

# Sorting features by importance
sorted_idx = np.argsort(feature_importance)[::-1]
sorted_features = feature_names[sorted_idx]
sorted_importances = feature_importance[sorted_idx]

# Displaying features and their approximate importance
for feature, importance in zip(sorted_features, sorted_importances):
    print(f"{feature}: {importance}")
# Out:
# StockOptionLevel: 0.4286088646103907
# YearsAtCompany: 0.41543665916976985
# YearsInCurrentRole: 0.39166023227177316
# MonthlyIncome: 0.37319174436255464
# Attendance: 0.3719099146644171
# OverTime: 0.36857258339619065
# YearsWithCurrManager: 0.36245505065364786
# JobLevel: 0.34482545992745156
# JobSatisfaction: 0.33710850081106064
# EnvironmentSatisfaction: 0.3369556077535075
# TotalWorkingYears: 0.3341364262233326
# Age: 0.3094374684744589
# MaritalStatus: 0.27644085009161384
# JobInvolvement: 0.2650985860084187
# PercentSalaryHike: 0.17823658620310104
# RelationshipSatisfaction: 0.1521242241772127
# Department: 0.12663154014378677
# DailyRate: 0.11953086273509811
# WorkLifeBalance: 0.11390766980207552
# YearsSinceLastPromotion: 0.11311441595679621
# DistanceFromHome: 0.10437126767663747
# JobRole: 0.08874736279612863
# NumCompaniesWorked: 0.08819294383895984
# EducationField: 0.05590278172589058
# Education: 0.048327352407889455
# EmployeeNumber: 0.03634455834002152
# ...

# %%
import matplotlib.pyplot as plt

# Ensure sorted_features and sorted_importances are available
# For demonstration, let's assume these are your features and importances
# sorted_features = ['feature1', 'feature2', 'feature3', ...]
# sorted_importances = [0.25, 0.15, 0.10, ...]

# Plotting
plt.figure(figsize=(10, 8))
plt.barh(range(len(sorted_importances)), sorted_importances, align='center')
plt.yticks(range(len(sorted_importances)), sorted_features)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances for Gaussian Naive Bayes Model')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature on top
plt.show()

# %%
X_train
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 1394   32               2       1373           1                 5          4
# 56     35               1        853           2                18          5
# 1249   29               2        428           2                 9          3
# 499    33               2       1216           2                 8          4
# 91     51               2        632           2                21          4
# ...   ...             ...        ...         ...               ...        ...
# 1371   56               2       1443           2                11          5
# 565    23               2        310           1                10          1
# 1343   29               2        592           1                 7          3
# 547    42               1        933           1                19          3
# 1381   28               0       1103           1                16          3
#
# ...

# %%
'''# Removing less important features
new_X_train= X_train.drop([  'EmployeeCount', 'Over18', 'StandardHours',
                      'TrainingTimesLastYear', 'MonthlyRate', 'BusinessTravel', 'HourlyRate',
                       'Gender', 'Education', 'MonthlyIncome', 'EducationField', 'DistanceFromHome',
                       'DailyRate', 'Department', 'WorkLifeBalance', 'YearsSinceLastPromotion',
                       'NumCompaniesWorked', 'JobRole', 'Gender','RelationshipSatisfaction','PercentSalaryHike','StockOptionLevel'], axis=1)
new_X_train'''
# Out:
# "# Removing less important features\nnew_X_train= X_train.drop([  'EmployeeCount', 'Over18', 'StandardHours',\n                      'TrainingTimesLastYear', 'MonthlyRate', 'BusinessTravel', 'HourlyRate',\n                       'Gender', 'Education', 'MonthlyIncome', 'EducationField', 'DistanceFromHome',\n                       'DailyRate', 'Department', 'WorkLifeBalance', 'YearsSinceLastPromotion',\n                       'NumCompaniesWorked', 'JobRole', 'Gender','RelationshipSatisfaction','PercentSalaryHike','StockOptionLevel'], axis=1)\nnew_X_train"

# %%
'''# Removing less important features
new_X_test = X_test.drop([ 'EmployeeCount', 'Over18', 'StandardHours',
                      'TrainingTimesLastYear', ((('MonthlyRate'))), 'BusinessTravel', ((('HourlyRate'))),
                       'Gender', ((('Education'))), ((('MonthlyIncome'))), 'EducationField', ((('DistanceFromHome'))),
                       ((('DailyRate'))), 'Department', ((('WorkLifeBalance'))), ((('YearsSinceLastPromotion'))),
                       ((('NumCompaniesWorked'))),((( 'JobRole'))), 'Gender','RelationshipSatisfaction',((('PercentSalaryHike'))),'StockOptionLevel'], axis=1)
new_X_test'''
# Out:
# "# Removing less important features\nnew_X_test = X_test.drop([ 'EmployeeCount', 'Over18', 'StandardHours',\n                      'TrainingTimesLastYear', ((('MonthlyRate'))), 'BusinessTravel', ((('HourlyRate'))),\n                       'Gender', ((('Education'))), ((('MonthlyIncome'))), 'EducationField', ((('DistanceFromHome'))),\n                       ((('DailyRate'))), 'Department', ((('WorkLifeBalance'))), ((('YearsSinceLastPromotion'))),\n                       ((('NumCompaniesWorked'))),((( 'JobRole'))), 'Gender','RelationshipSatisfaction',((('PercentSalaryHike'))),'StockOptionLevel'], axis=1)\nnew_X_test"

# %%
'''new_X_train= X_train.drop([ 'EmployeeCount', 'Over18', 'StandardHours','TrainingTimesLastYear','DailyRate'
                            ,'Education',"RelationshipSatisfaction","StandardHours",'EmployeeNumber'
                            ,"EmployeeCount", "JobInvolvement",'HourlyRate','PercentSalaryHike'
                            ,"StandardHours"], axis=1)'''
# Out:
# 'new_X_train= X_train.drop([ \'EmployeeCount\', \'Over18\', \'StandardHours\',\'TrainingTimesLastYear\',\'DailyRate\'\n                            ,\'Education\',"RelationshipSatisfaction","StandardHours",\'EmployeeNumber\'\n                            ,"EmployeeCount", "JobInvolvement",\'HourlyRate\',\'PercentSalaryHike\'\n                            ,"StandardHours"], axis=1)'

# %%
'''new_X_test = X_test.drop([ 'EmployeeCount', 'Over18', 'StandardHours','TrainingTimesLastYear','DailyRate'
                            ,'Education',"RelationshipSatisfaction","StandardHours",'EmployeeNumber'
                            ,"EmployeeCount", "JobInvolvement",'HourlyRate','PercentSalaryHike'
                            ,"StandardHours"], axis=1)'''
# Out:
# 'new_X_test = X_test.drop([ \'EmployeeCount\', \'Over18\', \'StandardHours\',\'TrainingTimesLastYear\',\'DailyRate\'\n                            ,\'Education\',"RelationshipSatisfaction","StandardHours",\'EmployeeNumber\'\n                            ,"EmployeeCount", "JobInvolvement",\'HourlyRate\',\'PercentSalaryHike\'\n                            ,"StandardHours"], axis=1)'

# %%
new_X_train= X_train.drop([ 'EmployeeCount', 'Over18', 'StandardHours','TrainingTimesLastYear','DailyRate'
                            ,'Education',"RelationshipSatisfaction","StandardHours"
                            ,"EmployeeCount",'HourlyRate','PercentSalaryHike'
                            ,"StandardHours",'BusinessTravel' , 'EmployeeCount' ,
                           'JobRole' ,  'MonthlyRate' ,
                            'TotalWorkingYears' , 'WorkLifeBalance' , 'YearsInCurrentRole' , 'YearsWithCurrManager'

], axis=1)

# %%
new_X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 530 entries, 1394 to 1381
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      530 non-null    int64
#  1   Department               530 non-null    int64
#  2   DistanceFromHome         530 non-null    int64
#  3   EducationField           530 non-null    int64
#  4   EmployeeNumber           530 non-null    int64
#  5   EnvironmentSatisfaction  530 non-null    int64
#  6   Gender                   530 non-null    int64
#  7   JobInvolvement           530 non-null    int64
#  8   JobLevel                 530 non-null    int64
#  9   JobSatisfaction          530 non-null    int64
#  10  MaritalStatus            530 non-null    int64
#  11  MonthlyIncome            530 non-null    int64
#  12  NumCompaniesWorked       530 non-null    int64
#  13  OverTime                 530 non-null    int64
# ...

# %%
new_X_test = X_test.drop([ 'EmployeeCount', 'Over18', 'StandardHours','TrainingTimesLastYear','DailyRate'
                            ,'Education',"RelationshipSatisfaction","StandardHours"
                            ,"EmployeeCount",'HourlyRate','PercentSalaryHike'
                            ,"StandardHours",'BusinessTravel' , 'EmployeeCount' ,
                              'JobRole' ,  'MonthlyRate' ,
                             'TotalWorkingYears' , 'WorkLifeBalance' , 'YearsInCurrentRole' , 'YearsWithCurrManager'], axis=1)

# %%
best_gnb = gs_NB.best_estimator_

# %%
new_Data_transformed_train_GN = PowerTransformer().fit_transform(new_X_train)
new_Data_transformed_test_GN = PowerTransformer().fit_transform(new_X_test)

# %%
best_gnb.fit(new_X_train, y_train);

# %%
# predict the target on the test dataset
predict_train_new = best_gnb.predict(new_X_train)
predict_test_new = best_gnb.predict(new_X_test)


# Accuracy Score on test dataset
accuracy_train_new = metrics.accuracy_score(y_train,predict_train_new)
accuracy_test_new = metrics.accuracy_score(y_test,predict_test_new)


print('accuracy_score on train dataset : ', accuracy_train_new)
print('accuracy_score on test dataset : '
, accuracy_test_new)
# Out:
# accuracy_score on train dataset :  0.8132075471698114
# accuracy_score on test dataset :  0.768361581920904

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predict_test_new))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.77      1.00      0.87       136
#          Yes       0.00      0.00      0.00        41
#
#     accuracy                           0.77       177
#    macro avg       0.38      0.50      0.43       177
# weighted avg       0.59      0.77      0.67       177

# %%
cm = confusion_matrix(y_test,predict_test_new)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class no', 'Class yes'], yticklabels=['Class no', 'Class yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix of enhanced Gaussian Naive Bayes')
plt.show()

# %%
# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predict_test_new))
# Out:
# Confusion Matrix:
# [[136   0]
#  [ 41   0]]

# %%
'''from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Assuming X_train, X_test, y_train, y_test are your training and testing data

# Logistic Regression
lr_model = LogisticRegression()
lr_model.fit(new_Data_transformed_train_GN, y_train)
lr_pred = lr_model.predict(new_Data_transformed_test_GN)

# Decision Trees
dt_model = DecisionTreeClassifier()
dt_model.fit(new_Data_transformed_train_GN, y_train)
dt_pred = dt_model.predict(new_Data_transformed_test_GN)

# Random Forest
rf_model = RandomForestClassifier()
rf_model.fit(new_Data_transformed_train_GN, y_train)
rf_pred = rf_model.predict(new_Data_transformed_test_GN)

# Gradient Boosting
gb_model = GradientBoostingClassifier()
gb_model.fit(new_Data_transformed_train_GN, y_train)
gb_pred = gb_model.predict(new_Data_transformed_test_GN)

# Support Vector Machine (SVM)
svm_model = SVC()
svm_model.fit(new_Data_transformed_train_GN, y_train)
svm_pred = svm_model.predict(new_Data_transformed_test_GN)

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier()
knn_model.fit(new_Data_transformed_train_GN, y_train)
knn_pred = knn_model.predict(new_Data_transformed_test_GN)

# Evaluate each model
models = {
    "Logistic Regression": lr_pred,
    "Decision Trees": dt_pred,
    "Random Forest": rf_pred,
    "Gradient Boosting": gb_pred,
    "SVM": svm_pred,
    "KNN": knn_pred
}

for name, pred in models.items():
    acc = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred, pos_label="Yes")
    recall = recall_score(y_test, pred, pos_label="Yes")
    f1 = f1_score(y_test, pred, pos_label="Yes")
    print(f"{name}:\n  Accuracy: {acc:.2f}\n  Precision: {precision:.2f}\n  Recall: {recall:.2f}\n  F1-score: {f1:.2f}\n")'''
# Out:
# 'from sklearn.model_selection import train_test_split\nfrom sklearn.linear_model import LogisticRegression\nfrom sklearn.tree import DecisionTreeClassifier\nfrom sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier\nfrom sklearn.svm import SVC\nfrom sklearn.neighbors import KNeighborsClassifier\nfrom sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score\n\n# Assuming X_train, X_test, y_train, y_test are your training and testing data\n\n# Logistic Regression\nlr_model = LogisticRegression()\nlr_model.fit(new_Data_transformed_train_GN, y_train)\nlr_pred = lr_model.predict(new_Data_transformed_test_GN)\n\n# Decision Trees\ndt_model = DecisionTreeClassifier()\ndt_model.fit(new_Data_transformed_train_GN, y_train)\ndt_pred = dt_model.predict(new_Data_transformed_test_GN)\n\n# Random Forest\nrf_model = RandomForestClassifier()\nrf_model.fit(new_Data_transformed_train_GN, y_train)\nrf_pred = rf_model.predict(new_Data_transformed_test_GN)\n\n# G
# ...

# %%
'''from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# Assuming X_train, X_test, y_train, y_test are your training and testing data

# Split the data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Define and train Gaussian Naive Bayes
gnb = GaussianNB(priors=[0.6, 0.4])
gnb.fit(X_train, y_train)

# Define and train other models with specified hyperparameters
dt = DecisionTreeClassifier(max_depth=5)  # Example hyperparameter: max_depth
dt.fit(X_train, y_train)

rf = RandomForestClassifier(n_estimators=100, max_depth=5)  # Example hyperparameters: n_estimators, max_depth
rf.fit(X_train, y_train)

gb = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3)  # Example hyperparameters: n_estimators, learning_rate, max_depth
gb.fit(X_train, y_train)

svm = SVC(kernel='linear', C=1.0)  # Example hyperparameters: kernel, C
svm.fit(X_train, y_train)

knn = KNeighborsClassifier(n_neighbors=5)  # Example hyperparameter: n_neighbors
knn.fit(X_train, y_train)

# Make predictions
gnb_pred = gnb.predict(X_test)
dt_pred = dt.predict(X_test)
rf_pred = rf.predict(X_test)
gb_pred = gb.predict(X_test)
svm_pred = svm.predict(X_test)
knn_pred = knn.predict(X_test)

# Evaluate each model
models = {
    "Gaussian Naive Bayes": gnb_pred,
    "Decision Tree": dt_pred,
    "Random Forest": rf_pred,
    "Gradient Boosting": gb_pred,
    "SVM": svm_pred,
    "KNN": knn_pred
}

for name, pred in models.items():
    acc = metrics.accuracy_score(y_test, pred)
    precision = metrics.precision_score(y_test, pred, pos_label="Yes")
    recall = metrics.recall_score(y_test, pred, pos_label="Yes")
    f1 = metrics.f1_score(y_test, pred, pos_label="Yes")
    print(f"{name}:\n  Accuracy: {acc:.2f}\n  Precision: {precision:.2f}\n  Recall: {recall:.2f}\n  F1-score: {f1:.2f}\n")'''
# Out:
# 'from sklearn.model_selection import train_test_split\nfrom sklearn.naive_bayes import GaussianNB\nfrom sklearn.tree import DecisionTreeClassifier\nfrom sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier\nfrom sklearn.svm import SVC\nfrom sklearn.neighbors import KNeighborsClassifier\nfrom sklearn import metrics\n\n# Assuming X_train, X_test, y_train, y_test are your training and testing data\n\n# Split the data into training and testing sets\n#X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)\n\n# Define and train Gaussian Naive Bayes\ngnb = GaussianNB(priors=[0.6, 0.4])\ngnb.fit(X_train, y_train)\n\n# Define and train other models with specified hyperparameters\ndt = DecisionTreeClassifier(max_depth=5)  # Example hyperparameter: max_depth\ndt.fit(X_train, y_train)\n\nrf = RandomForestClassifier(n_estimators=100, max_depth=5)  # Example hyperparameters: n_estimators, max_depth\nrf.fit(X_train, y_train)\n\ngb
# ...

# %%
'''from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier

# Define and train additional models
ada = AdaBoostClassifier(n_estimators=100)
ada.fit(X_train, y_train)

bagging = BaggingClassifier(n_estimators=100)
bagging.fit(X_train, y_train)

extra_trees = ExtraTreesClassifier(n_estimators=100, max_depth=5)
extra_trees.fit(X_train, y_train)

mlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000)
mlp.fit(X_train, y_train)

# Make predictions
ada_pred = ada.predict(X_test)
bagging_pred = bagging.predict(X_test)
extra_trees_pred = extra_trees.predict(X_test)
mlp_pred = mlp.predict(X_test)

# Evaluate each model
models = {
    "AdaBoost": ada_pred,
    "Bagging": bagging_pred,
    "Extra Trees": extra_trees_pred,
    "MLP": mlp_pred
}

for name, pred in models.items():
    acc = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred, pos_label="Yes")
    recall = recall_score(y_test, pred, pos_label="Yes")
    f1 = f1_score(y_test, pred, pos_label="Yes")
    print(f"{name}:\n  Accuracy: {acc:.2f}\n  Precision: {precision:.2f}\n  Recall: {recall:.2f}\n  F1-score: {f1:.2f}\n")
'''
# Out:
# 'from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier\nfrom sklearn.neural_network import MLPClassifier\n\n# Define and train additional models\nada = AdaBoostClassifier(n_estimators=100)\nada.fit(X_train, y_train)\n\nbagging = BaggingClassifier(n_estimators=100)\nbagging.fit(X_train, y_train)\n\nextra_trees = ExtraTreesClassifier(n_estimators=100, max_depth=5)\nextra_trees.fit(X_train, y_train)\n\nmlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000)\nmlp.fit(X_train, y_train)\n\n# Make predictions\nada_pred = ada.predict(X_test)\nbagging_pred = bagging.predict(X_test)\nextra_trees_pred = extra_trees.predict(X_test)\nmlp_pred = mlp.predict(X_test)\n\n# Evaluate each model\nmodels = {\n    "AdaBoost": ada_pred,\n    "Bagging": bagging_pred,\n    "Extra Trees": extra_trees_pred,\n    "MLP": mlp_pred\n}\n\nfor name, pred in models.items():\n    acc = accuracy_score(y_test, pred)\n    precision = precision_score(y_test, pred, pos_label="Yes
# ...

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import os
import matplotlib.pyplot as plt
import pandas_datareader as web
import datetime as dt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.callbacks import EarlyStopping
from keras.layers import Activation

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import KFold
from statistics import mean

from mlxtend.frequent_patterns import apriori, association_rules

import warnings
warnings.filterwarnings("ignore")

# %%
mlp = MLPClassifier()

# %%
from sklearn.model_selection import GridSearchCV
# Define the hyperparameters to tune
param_grid = {
    'solver': ['adam', 'sgd'],
    'activation': ['relu','logistic'],
   'hidden_layer_sizes':[90,100,104,105,120],
    'max_iter':[90,100,104,105,120],
    'alpha':[0.01,0.02,0.05]
}

# Perform GridSearchCV to find the best hyperparameters
grid = GridSearchCV(estimator=mlp, param_grid=param_grid, cv=5)
grid_result = grid.fit(new_X_train, y_train)

# Print the best hyperparameters and accuracy
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.815094 using {'activation': 'relu', 'alpha': 0.02, 'hidden_layer_sizes': 105, 'max_iter': 105, 'solver': 'sgd'}

# %%
mlp = MLPClassifier(alpha= 0.05, hidden_layer_sizes=(100, ), activation='relu', solver='adam', max_iter=120)

# %%
 from sklearn import metrics
mlp.fit(new_X_train,y_train)
y_train_pred = mlp.predict(new_X_train)
y_test_pred = mlp.predict(new_X_test)
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred))
print('Accuracy Score on test data: ', metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Accuracy Score on train data:  0.8132075471698114
# Accuracy Score on test data:  0.768361581920904

# %%
predictions = mlp.predict(new_X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.77      1.00      0.87       136
#          Yes       0.00      0.00      0.00        41
#
#     accuracy                           0.77       177
#    macro avg       0.38      0.50      0.43       177
# weighted avg       0.59      0.77      0.67       177

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[136   0]
#  [ 41   0]]

# %%
cm = confusion_matrix(y_test,predictions)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
def LSTM_model():
    """
    Create and configure an LSTM model for stock price prediction.

    :return: The configured LSTM model (keras.Sequential)
    """

    # Initialize a sequential model
    model = Sequential()

    # Add the first LSTM layer with 50 units, input shape, and return sequences
    model.add(LSTM(units=14, return_sequences=True, input_shape=(new_X_train.shape[1], 1)))
    # Add dropout to prevent overfitting
    model.add(Dropout(0.2))

    # Add a second LSTM layer with 50 units and return sequences
    model.add(LSTM(units=21, return_sequences=True))
    # Add dropout to prevent overfitting
    model.add(Dropout(0.2))


    # Add a dense output layer with one unit
    model.add(Dense(units=1))

    return model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense

# Build the B-LSTM model
model = tf.keras.Sequential([
    # Input layer
tf.keras.layers.InputLayer((new_X_train.shape[1], 1)),

    # Hidden layer with ReLU activation
tf.keras.layers.Dense(21, activation='relu'),

    # Output layer with Sigmoid activation for binary classification
tf.keras.layers.Dense(1,activation='sigmoid')
])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Assuming you have input features X and labels y
# Build the BI-LSTM model
model1 = Sequential([
    Bidirectional(LSTM(21, activation='relu'), input_shape=(new_X_train.shape[1], 1)),
    Dense(1, activation='sigmoid')
])

# %%
int_y_train=label_encoder.fit_transform(y_train)

# %%
y_train_float = int_y_train.astype(np.float32)
new_X_train_float = new_X_train.astype(np.float32)

# %%
# Compile the model
model1.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
# Train the model
model1.fit(new_X_train_float, y_train_float, epochs=170, batch_size=32)
# Out:
# Epoch 1/170
# 17/17 [==============================] - 3s 18ms/step - loss: 0.6295 - accuracy: 0.3660
# Epoch 2/170
# 17/17 [==============================] - 0s 13ms/step - loss: 0.8019 - accuracy: 0.1981
# Epoch 3/170
# 17/17 [==============================] - 0s 12ms/step - loss: 0.8113 - accuracy: 0.1887
# Epoch 4/170
# 17/17 [==============================] - 0s 12ms/step - loss: 0.8113 - accuracy: 0.1887
# Epoch 5/170
# 17/17 [==============================] - 0s 11ms/step - loss: 0.8075 - accuracy: 0.1925
# Epoch 6/170
# 17/17 [==============================] - 0s 12ms/step - loss: 0.8094 - accuracy: 0.1906
# Epoch 7/170
# 17/17 [==============================] - 0s 17ms/step - loss: 0.8094 - accuracy: 0.1906
# Epoch 8/170
# 17/17 [==============================] - 0s 16ms/step - loss: 0.8094 - accuracy: 0.1906
# Epoch 9/170
# 17/17 [==============================] - 0s 16ms/step - loss: 0.8094 - accuracy: 0.1906
# Epoch 10/170
# ...

# %%
int_y_test=label_encoder.fit_transform(y_test)
y_test_float = int_y_test.astype(np.float32)

# %%
new_X_test_float = new_X_test.astype(np.float32)

# %%
# Evaluate the model on the test set
loss, accuracy = model1.evaluate(new_X_test_float, y_test_float)
print(f'Binary Crossentropy Loss on Test Data: {loss}')
print(f'Accuracy on Test Data: {accuracy}')
# Out:
# 6/6 [==============================] - 1s 6ms/step - loss: 0.7684 - accuracy: 0.2316
# Binary Crossentropy Loss on Test Data: 0.7683615684509277
# Accuracy on Test Data: 0.23163841664791107

# %%
predictions2 = model1.predict(new_X_test_float)
binary_predictions2 = (predictions2 > 0.5).astype(int)
# Out:
# 6/6 [==============================] - 0s 6ms/step

# %%
cm = confusion_matrix(y_test_float,binary_predictions2)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

plt.show()

# %%
# Define the KNN model
from sklearn.model_selection import GridSearchCV
knn = KNeighborsClassifier()

# Define the hyperparameters to search
param_grid = {'n_neighbors': [1, 3, 5, 7, 9,10,12,26,20,25,30]}

# Create the grid search object
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, scoring='accuracy', cv=10)

# Perform the grid search on the training data
grid_search.fit(new_X_train, y_train)

# Print the best hyperparameters found
print("Best Hyperparameters:", grid_search.best_params_)

# Get the best model
best_knn = grid_search.best_estimator_
# Out:
# Best Hyperparameters: {'n_neighbors': 26}

# %%
from sklearn import metrics
knn = KNeighborsClassifier(n_neighbors= 12)
knn.fit(new_X_train,y_train)
y_train_pred3 = knn.predict(new_X_train)
y_test_pred3 = knn.predict(new_X_test)
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train, y_train_pred3))
print('Accuracy Score on test data: ', metrics.accuracy_score(y_test, y_test_pred3))
# Out:
# Accuracy Score on train data:  0.8113207547169812
# Accuracy Score on test data:  0.768361581920904

# %%
predictions4 = knn.predict(new_X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predictions4))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.77      1.00      0.87       136
#          Yes       0.00      0.00      0.00        41
#
#     accuracy                           0.77       177
#    macro avg       0.38      0.50      0.43       177
# weighted avg       0.59      0.77      0.67       177

# %%
cm = confusion_matrix(y_test,predictions4)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
LR=LogisticRegression()
LR.fit(new_X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = LR.predict(new_X_train)

# %%
y_pred_test = LR.predict(new_X_test)

# %%
print("The classification report \n")
print(classification_report(y_test,y_pred_test))
# Out:
# The classification report
#
#               precision    recall  f1-score   support
#
#           No       0.79      0.99      0.88       136
#          Yes       0.71      0.12      0.21        41
#
#     accuracy                           0.79       177
#    macro avg       0.75      0.55      0.54       177
# weighted avg       0.77      0.79      0.72       177

# %%
print('Accuracy Score on train data: ', metrics.accuracy_score(y_train,y_pred_train))
print("LR test Accuracy:", metrics.accuracy_score(y_test,y_pred_test))
# Out:
# Accuracy Score on train data:  0.8207547169811321
# LR test Accuracy: 0.7853107344632768

# %%
from sklearn.metrics import confusion_matrix
cm = (confusion_matrix(y_test,y_pred_test))
cmdf = pd.DataFrame(cm,index=['B','M'], columns=['B','M'])
print("The confusion matrix looks like following...\n")
cmdf
# Out:
# The confusion matrix looks like following...
#      B  M
# B  134  2
# M   36  5

# %%
# prompt: naive bayes

from sklearn.naive_bayes import GaussianNB

# Define the Gaussian Naive Bayes model
gnb = GaussianNB()

# Train the model using the training data
gnb.fit(new_X_train, y_train)

y_pred_gnb_train = gnb.predict(new_X_train)

# Evaluate the accuracy of the model
accuracy_gnb_train = accuracy_score(y_train, y_pred_gnb_train)

# Print the accuracy
print("Accuracy of the Naive Bayes model train:", accuracy_gnb_train)


# Predict the labels for the test data
y_pred_gnb_test = gnb.predict(new_X_test)

# Evaluate the accuracy of the model
accuracy_gnb_test = accuracy_score(y_test, y_pred_gnb_test)

# Print the accuracy
print("Accuracy of the Naive Bayes model test:", accuracy_gnb_test)
# Out:
# Accuracy of the Naive Bayes model train: 0.8471698113207548
# Accuracy of the Naive Bayes model test: 0.8531073446327684

# %%
print("The classification report \n")
print(classification_report(y_test,y_pred_gnb_test))
# Out:
# The classification report
#
#               precision    recall  f1-score   support
#
#           No       0.88      0.94      0.91       136
#          Yes       0.74      0.56      0.64        41
#
#     accuracy                           0.85       177
#    macro avg       0.81      0.75      0.77       177
# weighted avg       0.85      0.85      0.85       177

# %%
# prompt: naive bayes

from sklearn.naive_bayes import GaussianNB

# Define the Gaussian Naive Bayes model
gnb = GaussianNB()

# Train the model using the training data
gnb.fit(X_train, y_train)

y_pred_gnb_train = gnb.predict(X_train)

# Evaluate the accuracy of the model
accuracy_gnb_train = accuracy_score(y_train, y_pred_gnb_train)

# Print the accuracy
print("Accuracy of the Naive Bayes model train:", accuracy_gnb_train)


# Predict the labels for the test data
y_pred_gnb_test = gnb.predict(X_test)

# Evaluate the accuracy of the model
accuracy_gnb_test = accuracy_score(y_test, y_pred_gnb_test)

# Print the accuracy
print("Accuracy of the Naive Bayes model test:", accuracy_gnb_test)
# Out:
# Accuracy of the Naive Bayes model train: 0.8132075471698114
# Accuracy of the Naive Bayes model test: 0.8248587570621468

# %%
print("The classification report \n")
print(classification_report(y_test,y_pred_gnb_test))
# Out:
# The classification report
#
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       136
#          Yes       0.63      0.59      0.61        41
#
#     accuracy                           0.82       177
#    macro avg       0.75      0.74      0.75       177
# weighted avg       0.82      0.82      0.82       177

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

cv_method = RepeatedStratifiedKFold(n_splits=5,
                                    n_repeats=3,
                                    random_state=999)

# %%
from sklearn.preprocessing import PowerTransformer
import sklearn.preprocessing

#from sklearn.preprocessing import BoxCoxTransformer
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=gnb,
                     param_grid=params_NB,
                     cv=cv_method,
                     verbose=1,
                     scoring='accuracy')

'''sklearn.preprocessing.power_transform(X, method='box-cox',  standardize=True, copy=True)
Data_transformed_train = BoxCoxTransformer().fit_transform(X_train)
Data_transformed_test = BoxCoxTransformer().fit_transform(X_test)'''
import sklearn.preprocessing
#from sklearn.preprocessing import BoxCoxTransformer

#Data_transformed_train = BoxCoxTransformer().fit_transform(X_train)

Data_transformed_train = PowerTransformer().fit_transform(new_X_train)
Data_transformed_test = PowerTransformer().fit_transform(new_X_test)
#Data_transformed_train = X_train
#Data_transformed_test = X_test

# %%
gs_NB.fit(Data_transformed_train, y_train);
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits

# %%
gs_NB.best_params_
# Out:
# {'var_smoothing': 0.43287612810830584}

# %%
gs_NB.best_score_
# Out:
# 0.8528301886792454

# %%
best_gnb = gs_NB.best_estimator_

# %%
best_gnb.fit(Data_transformed_train, y_train);

# %%
# predict the target on the test dataset
predict_train = best_gnb.predict(Data_transformed_train)
predict_test = best_gnb.predict(Data_transformed_test)


# Accuracy Score on test dataset
accuracy_train = metrics.accuracy_score(y_train,predict_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)


print('accuracy_score on train dataset : ', accuracy_train)
print('accuracy_score on test dataset : '
, accuracy_test)
# Out:
# accuracy_score on train dataset :  0.8716981132075472
# accuracy_score on test dataset :  0.8531073446327684

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predict_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.85      0.98      0.91       136
#          Yes       0.86      0.44      0.58        41
#
#     accuracy                           0.85       177
#    macro avg       0.85      0.71      0.75       177
# weighted avg       0.85      0.85      0.83       177
